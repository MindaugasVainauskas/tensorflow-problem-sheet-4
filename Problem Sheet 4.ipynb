# %%
#This is a problem sheet 4 solution Jupyter notebook

# %%
# Adapted from in class example given in: https://github.com/emerging-technologies/keras-iris
# Part-1. Use tensorflow to create the models.
# In this cell models will be created from imported iris.csv file containing Iris dataset.

# Import the libraries
import keras as ke
import csv
import numpy as np

#Populate Iris data set
# CSV file from: https://sourceforge.net/projects/irisdss/files/IRIS.csv/download
irisData = list(csv.reader(open('iris.csv')))

# sizes are the sizes of data set.  Petal length and width, sepal length and width
sizes = np.array(irisData)[:,:4].astype(np.float)

# 3 species of iris exist in the dataset: Setosa, Versicolor and Virginica.
species = np.array(irisData)[:,4]

# Change species strings to integer values to create enum later
species_values, species_ints = np.unique(species, return_inverse=True)
# Encode the species integers as bin categorical variables.
species_cats = ke.utils.to_categorical(species_ints)
# Out:
# Using TensorFlow backend.

# %%
#Part-2 Split data into training and testing

 # Generate random permutation dependent on length of the sizes array
ran_perm = np.random.permutation(len(sizes)) 

# Split the permutation into training and testing set length variables
train_set, test_set = np.array_split(ran_perm, 2) 

# Split the data into training and testing sets. Their lengths are decided by previously created length variables
sizes_train, species_train = sizes[train_set], species_cats[train_set]
sizes_test,  species_test  = sizes[test_set],  species_cats[test_set]

# %%
#Part-3 Train the model.
# In this cell model training will take place.

#Create the Keras model
model = ke.models.Sequential()

# Add an initial layer with 4 input nodes, and a hidden layer with 16 nodes.
model.add(ke.layers.Dense(16, input_shape=(4,)))
# Apply the sigmoid activation function to that layer.
model.add(ke.layers.Activation("sigmoid"))
# Add another layer, connected to the layer with 16 nodes, containing three output nodes.
model.add(ke.layers.Dense(3))
# Use the softmax activation function there.
model.add(ke.layers.Activation("softmax"))

#Prepare the model. Optimizer used is Adam Algorithm. 
#Cost is calculated with categorical crossentropy. Accuracy is metric needed to see how good the training is
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Fit the model with the sets created above.
# Model will run 100 times(epochs). It will run 1 sample per gradient update.
# Verbose mode -- 0 - no feedback until done, 1 - progress bar for every epoch, 2 - single line per epoch
model.fit(sizes_train, species_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 19ms/step - loss: 1.1098 - acc: 0.3200
# Epoch 2/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.0467 - acc: 0.4133
# Epoch 3/100
# 75/75 [==============================] - 0s 5ms/step - loss: 1.0039 - acc: 0.6667
# Epoch 4/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9642 - acc: 0.7067
# Epoch 5/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.9252 - acc: 0.7067
# Epoch 6/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8736 - acc: 0.7067
# Epoch 7/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.8291 - acc: 0.7067
# Epoch 8/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7874 - acc: 0.7067
# Epoch 9/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7404 - acc: 0.7200
# Epoch 10/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.6944 - acc: 0.7600
# Epoch 11/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0
100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2232 - acc: 0.9600
# Epoch 65/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2209 - acc: 0.9600
# Epoch 66/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2152 - acc: 0.9600
# Epoch 67/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2120 - acc: 0.9600
# Epoch 68/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.2085 - acc: 0.9600
# Epoch 69/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2051 - acc: 0.9733
# Epoch 70/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2026 - acc: 0.9600
# Epoch 71/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1976 - acc: 0.9733
# Epoch 72/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1978 - acc: 0.9600
# Epoch 73/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1934 - acc: 0.9600
# Epoch 74/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1892 - acc: 0.9600
# Epoch 75/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1865 - acc: 0.9600
# Epoch 76/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1829 - acc: 0.9733
# Epoch 77/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1843 - acc: 0.9733
# Epoch 78/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1795 - acc: 0.9600
# Epoch 79/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1784 - acc: 0.9600
# Epoch 80/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1747 - acc: 0.9733
# Epoch 81/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1753 - acc: 0.9600
# Epoch 82/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1721 - acc: 0.9600
# Epoch 83/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1721 - acc: 0.9733
# Epoch 84/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1678 - acc: 0.9733
# Epoch 85/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1624 - acc: 0.9733
# Epoch 86/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1609 - acc: 0.9733
# Epoch 87/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1587 - acc: 0.9600A: 0s - loss: 0.1460 - acc:
# Epoch 88/100
# 75/75 [==============================] - ETA: 0s - loss: 0.1458 - acc: 0.985 - 0s 5ms/step - loss: 0.1588 - acc: 0.9600
# Epoch 89/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1534 - acc: 0.9733
# Epoch 90/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1518 - acc: 0.9600
# Epoch 91/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1526 - acc: 0.9600
# Epoch 92/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1514 - acc: 0.9733
# Epoch 93/100
# 75/75 [==============================] - ETA: 0s - loss: 0.1443 - acc: 0.954 - 0s 5ms/step - loss: 0.1477 - acc: 0.9600
# Epoch 94/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1460 - acc: 0.9600
# Epoch 95/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1451 - acc: 0.9733
# Epoch 96/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1406 - acc: 0.9733
# Epoch 97/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1408 - acc: 0.9600
# Epoch 98/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1386 - acc: 0.9600
# Epoch 99/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1407 - acc: 0.9600
# Epoch 100/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1381 - acc: 0.9600

# %%
#Part-4 Test the model
# In this cell model will be evaluated and tested to find a species of a random flower from the dataset

# Evaluate the model
cost, accuracy = model.evaluate(sizes_test, species_test, verbose=1)

# Print out the cost and accuracy of the model
print("\n\nCost: %5.3f\tAccuracy: %5.3f%%" % (cost, accuracy*100))

# Predict the species of a single flower.
iris_pred = np.around(model.predict(np.expand_dims(sizes_test[0], axis=0))).astype(np.int)[0]
print("Actual value bool: %s\tEstimated species bool: %s" % (species_test[0].astype(np.int), iris_pred))
print("Species is %s" % species_values[iris_pred.astype(np.bool)][0])

# Save the model to a file for later use.
model.save("iris_model.h5")
# Load the saved model when needed later: model = load_model("iris_model.h5")
# Out:
# 75/75 [==============================] - 0s 838us/step
#
#
# Cost: 0.135	Accuracy: 97.333%
# Actual value bool: [1 0 0]	Estimated species bool: [1 0 0]
# Species is a Iris-setosa
